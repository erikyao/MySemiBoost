# %%
import pandas as pd

# %%
osu18 = pd.read_csv("C:\\Users\\Yao Yao\\Documents\\Workspace\\python\\MySemiBoost_Proj\\feature_matrix_osu18_cn.tsv", sep="\t")

# %%
osu18.shape
# Out:
# (39083, 249)

# %%
osu18.head()
# Out:
#          name chrom majorAllele  majorAlleleFreq minorAllele  minorAlleleFreq  \
# 0   rs3737721  chr1           A         0.771965           G         0.228035
# 1  rs12041067  chr1           C         0.776158           A         0.223842
# 2   rs2297234  chr1           G         0.829872           T         0.170128
# 3   rs2297233  chr1           C         0.777955           A         0.222045
# 4   rs2296476  chr1           G         0.777157           A         0.222843
#
#    normChromCoord  tfCount  tf_ARID3A  tf_ATF1  ...     avg_het  cpg_island  \
# 0        0.004926      0.0          0        0  ...    0.034143           0
# 1        0.004937      0.0          0        0  ...    0.144331           0
# 2        0.004949      0.0          0        0  ...    0.135394           0
# 3        0.004950      0.0          0        0  ...    0.092343           0
# 4        0.004965      6.0          0        0  ...    0.069127           0
#
# ...
